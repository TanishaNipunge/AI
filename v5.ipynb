# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\tanis\Downloads\Mall_Customers.csv')
print(df)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
plt.title('Unclustered Data')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.scatter(x[:, 0], x[:, 1])  # Use integer indices to access the columns
plt.show()

# %%
from sklearn.cluster import KMeans
wcss=[]
for k in range(1,11):
    km=KMeans(n_clusters=k)
    km.fit_predict(x)
    wcss.append(km.inertia_)
plt.title('Elbow Method ')
plt.xlabel('Value of K ')
plt.ylabel('WCSS')
plt.grid()
plt.xticks(range(1,11))
plt.plot(range(1,11),wcss,color='red',marker='.')
# Out:
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
from sklearn.metrics import silhouette_score
silh=[]
for i in range(2,11):
    km=KMeans(n_clusters=i)
    label=km.fit_predict(x)
    score=silhouette_score(x,label)
    silh.append(score)

plt.title('Silhouette Score ')
plt.xlabel('value of K')
plt.ylabel('silhouette score ')
plt.bar(range(2,11),silh,color='red')
# Out:
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
plt.title('Unclustered')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.scatter(x[:,0],x[:,1])

km=KMeans(n_clusters=5,random_state=42)
label=km.fit_predict(x)
plt.figure(figsize=(9,9))
plt.title('Clustered')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.scatter(x[:,0],x[:,1],c=label)

cent=km.cluster_centers_
plt.scatter(cent[:,0],cent[:,1],color='black',s=300,label='cent',marker='.')
# Out:
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
